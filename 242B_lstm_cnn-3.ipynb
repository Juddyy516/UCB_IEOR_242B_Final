# %% [markdown]
# # **Preprocess audio files**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import soundfile as sf
import librosa
import librosa.display
from IPython.display import Audio
from tqdm import tqdm
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, LSTM, Bidirectional, GRU, BatchNormalization, LeakyReLU
from keras.utils import to_categorical
import os
import math
import json
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Path to the dataset and JSON output file

DATASET_PATH = '/content/drive/My Drive/242B/genres_original'
JSON_PATH = '/content/drive/My Drive/242B/mfcc.json'
'''
DATASET_PATH = '/content/drive/My Drive/242B Final Project/Data/genres_original'
JSON_PATH = '/content/drive/My Drive/242B Final Project/Data/mfcc.json'
'''
# Audio configuration parameters
SAMPLE_RATE = 22050
DURATION = 30  # Duration in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * DURATION

# %%
def save_mfcc(dataset_path, json_path, n_mfcc=13, n_fft=4084, hop_length=1024, num_segments=10):
    #dictionary to store data
    data = {
        'mapping' : [],
        'mfcc' : [],
        'labels' : []
    }

    count = 0
    num_samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    expected_num_mfcc_vectors_per_segment = math.ceil(num_samples_per_segment / hop_length)


    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        if dirpath not in dataset_path:

            dirpath_components = dirpath.split('/')
            semantic_label = dirpath_components[-1]
            data['mapping'].append(semantic_label)
            print('\nProcessing {}'.format(semantic_label))

            for f in filenames:
                if f.endswith('.wav') and f != 'jazz.00054.wav': # jazz.00054.wav is an empty file

                    file_path = os.path.join(dirpath,f)

                    #loading the audio file
                    signal, sr = sf.read(file_path)
                    # len(signal) = 661794  # sr is 22050 by default

                    #process segments extracting mfcc and storing data
                    for s in range(num_segments):
                        # Since num_segments is defined as 5. Every 30 sec file is divided into 5 segments of length 6sec
                        # Start sample would keep track of the index of the first element of each 6 second batch
                        # finish sample would keep track of the index of the last element of each 6 second batch
                        # And then with the help of python's slice functionality we will extract that 6 second batch from every 30 sec signal
                        start_sample = num_samples_per_segment * s
                        finish_sample = num_samples_per_segment + start_sample

                        # we need to extract, Usually n_mfcc is set b/w 13 to 40. The other parameters n_fft and hop length are

                        mfcc = librosa.feature.mfcc(y=signal[start_sample:finish_sample],sr=sr, n_mfcc=n_mfcc, n_fft=n_fft, hop_length=hop_length)

                        mfcc = mfcc.T
                        if len(mfcc) == expected_num_mfcc_vectors_per_segment:
                            print(mfcc.shape)
                            data['mfcc'].append(mfcc.tolist())
                            data['labels'].append(i)
                            print('Processing {}, segment:{}'.format(file_path, s))
                            count += 1
                            print(count)
    with open(json_path, 'w') as fp:
        json.dump(data, fp, indent=4)

# %%
save_mfcc(DATASET_PATH, JSON_PATH, num_segments=10)
# Out:
# Streaming output truncated to the last 5000 lines.
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00042.wav, segment:4
# 8324
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00042.wav, segment:5
# 8325
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00042.wav, segment:6
# 8326
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00042.wav, segment:7
# 8327
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00042.wav, segment:8
# 8328
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00042.wav, segment:9
# 8329
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00036.wav, segment:0
# 8330
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00036.wav, segment:1
# 8331
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00036.wav, segment:2
# 8332
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00036.wav, segment:3
# 8333
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00036.wav, segment:4
# 8334
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00036.wav, segment:5
# 8335
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00036.wav, segment:6
# 8336
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00036.wav, segment:7
# 8337
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00036.wav, segment:8
# 8338
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00036.wav, segment:9
# 8339
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00034.wav, segment:0
# 8340
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00034.wav, segment:1
# 8341
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00034.wav, segment:2
# 8342
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00034.wav, segment:3
# 8343
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00034.wav, segment:4
# 8344
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00034.wav, segment:5
# 8345
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00034.wav, segment:6
# 8346
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00034.wav, segment:7
# 8347
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/reggae/reggae.00034.wav, segment
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00086.wav, segment:9
# 9889
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00089.wav, segment:0
# 9890
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00089.wav, segment:1
# 9891
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00089.wav, segment:2
# 9892
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00089.wav, segment:3
# 9893
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00089.wav, segment:4
# 9894
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00089.wav, segment:5
# 9895
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00089.wav, segment:6
# 9896
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00089.wav, segment:7
# 9897
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00089.wav, segment:8
# 9898
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00089.wav, segment:9
# 9899
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00090.wav, segment:0
# 9900
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00090.wav, segment:1
# 9901
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00090.wav, segment:2
# 9902
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00090.wav, segment:3
# 9903
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00090.wav, segment:4
# 9904
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00090.wav, segment:5
# 9905
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00090.wav, segment:6
# 9906
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00090.wav, segment:7
# 9907
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00090.wav, segment:8
# 9908
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00090.wav, segment:9
# 9909
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00092.wav, segment:0
# 9910
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00092.wav, segment:1
# 9911
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00092.wav, segment:2
# 9912
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00092.wav, segment:3
# 9913
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00092.wav, segment:4
# 9914
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00092.wav, segment:5
# 9915
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00092.wav, segment:6
# 9916
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00092.wav, segment:7
# 9917
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00092.wav, segment:8
# 9918
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00092.wav, segment:9
# 9919
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00093.wav, segment:0
# 9920
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00093.wav, segment:1
# 9921
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00093.wav, segment:2
# 9922
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00093.wav, segment:3
# 9923
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00093.wav, segment:4
# 9924
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00093.wav, segment:5
# 9925
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00093.wav, segment:6
# 9926
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00093.wav, segment:7
# 9927
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00093.wav, segment:8
# 9928
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00093.wav, segment:9
# 9929
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00096.wav, segment:0
# 9930
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00096.wav, segment:1
# 9931
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00096.wav, segment:2
# 9932
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00096.wav, segment:3
# 9933
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00096.wav, segment:4
# 9934
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00096.wav, segment:5
# 9935
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00096.wav, segment:6
# 9936
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00096.wav, segment:7
# 9937
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00096.wav, segment:8
# 9938
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00096.wav, segment:9
# 9939
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00098.wav, segment:0
# 9940
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00098.wav, segment:1
# 9941
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00098.wav, segment:2
# 9942
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00098.wav, segment:3
# 9943
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00098.wav, segment:4
# 9944
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00098.wav, segment:5
# 9945
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00098.wav, segment:6
# 9946
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00098.wav, segment:7
# 9947
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00098.wav, segment:8
# 9948
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00098.wav, segment:9
# 9949
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00095.wav, segment:0
# 9950
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00095.wav, segment:1
# 9951
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00095.wav, segment:2
# 9952
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00095.wav, segment:3
# 9953
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00095.wav, segment:4
# 9954
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00095.wav, segment:5
# 9955
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00095.wav, segment:6
# 9956
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00095.wav, segment:7
# 9957
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00095.wav, segment:8
# 9958
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00095.wav, segment:9
# 9959
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00097.wav, segment:0
# 9960
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00097.wav, segment:1
# 9961
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00097.wav, segment:2
# 9962
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00097.wav, segment:3
# 9963
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00097.wav, segment:4
# 9964
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00097.wav, segment:5
# 9965
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00097.wav, segment:6
# 9966
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00097.wav, segment:7
# 9967
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00097.wav, segment:8
# 9968
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00097.wav, segment:9
# 9969
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00094.wav, segment:0
# 9970
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00094.wav, segment:1
# 9971
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00094.wav, segment:2
# 9972
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00094.wav, segment:3
# 9973
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00094.wav, segment:4
# 9974
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00094.wav, segment:5
# 9975
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00094.wav, segment:6
# 9976
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00094.wav, segment:7
# 9977
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00094.wav, segment:8
# 9978
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00094.wav, segment:9
# 9979
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00099.wav, segment:0
# 9980
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00099.wav, segment:1
# 9981
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00099.wav, segment:2
# 9982
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00099.wav, segment:3
# 9983
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00099.wav, segment:4
# 9984
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00099.wav, segment:5
# 9985
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00099.wav, segment:6
# 9986
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00099.wav, segment:7
# 9987
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00099.wav, segment:8
# 9988
# (65, 13)
# Processing /content/drive/My Drive/242B/genres_original/country/country.00099.wav, segment:9
# 9989

# %%
# loading the saved Json file
def load_data(path):
    with open(path, 'r') as fp:
        data = json.load(fp)

    #Convert lists into numpy arrays
    inputs = data['mfcc']
    targets = data['labels']
    return np.array(inputs), np.array(targets)

# %%
inputs, targets = load_data('/content/drive/My Drive/242B/mfcc.json')
#inputs, targets = load_data('/content/drive/My Drive/242B Final Project/Data/mfcc.json')

# %%
print(inputs)
# Out:
# [[[-8.21261387e+01  6.23185694e+01  4.08765672e+01 ... -1.11768220e+00
#    -6.75119693e+00 -8.29599796e+00]
#   [-6.53184250e+01  5.62508257e+01  3.39085210e+01 ... -7.61673737e-01
#    -5.05098528e+00 -4.51203877e+00]
#   [ 1.71854014e+01  4.35625807e+01  1.36640143e+01 ... -1.05185946e+00
#    -8.01901117e+00  5.85106676e+00]
#   ...
#   [ 4.67913523e+01  4.54541846e+01  7.96396950e+00 ... -8.57797524e-01
#    -1.08835093e+01 -2.25940695e+00]
#   [ 3.30745841e+01  4.77469152e+01  1.90245913e+01 ...  6.02257979e-02
#    -4.38458415e+00  1.12224241e+00]
#     2.01057248e+01 -2.29617114e+01]
#   [ 6.26578761e+01  7.16443829e+01 -2.26565121e+00 ... -9.44250806e+00
#     1.65990878e+01 -1.20912099e+01]]
#
#  [[ 9.55664968e+00  8.73019819e+01 -7.20290525e+00 ... -2.62161485e+00
#     4.77153449e+00 -8.60431398e+00]
#   [ 4.04833931e+01  9.42983366e+01 -1.35894319e+01 ... -1.10596499e+01
#     5.12843302e+00 -9.63133684e+00]
#   [ 2.37729735e+01  1.07468068e+02 -1.89654328e+01 ... -1.58431748e+01
#     9.82397370e+00 -1.56111134e+01]
#   ...
#   [ 5.34863533e+01  8.64297542e+01 -2.08339779e+01 ... -4.03317722e-01
#     3.09597865e+01 -3.26626673e+00]
#   [ 3.45586870e+01  7.94933979e+01 -2.18504636e+01 ... -2.05104305e+00
#     3.22292181e+01  2.42940035e-01]
#   [ 2.46142371e+01  6.98475155e+01 -1.47177631e+01 ...  9.48817928e+00
#     3.33086329e+01  9.07967554e+00]]]

# %%
print(targets)
# Out:
# [ 1  1  1 ... 10 10 10]

# %%
inputs.shape
# Out:
# (9989, 65, 13)

# %%
inputs_train, inputs_test, targets_train, targets_test = train_test_split(inputs, targets, test_size=0.2)

# %% [markdown]
# Add Noise

# %%
for i in range(inputs_train.shape[0]):
    s = np.random.rand(inputs_train.shape[1], inputs_train.shape[2])
    inputs_train[i] = inputs_train[i] + s

# %%
targets_train -= 1
targets_test -= 1

# %% [markdown]
# # **LSTM**

# %%
lstm_model_1 = Sequential([
    LSTM(32, return_sequences=True, input_shape=(inputs.shape[1], inputs.shape[2])),
    LSTM(64, return_sequences=True),
    LSTM(128),
    LeakyReLU(),
    Flatten(),
    Dense(128),
    LeakyReLU(),
    Dense(10, activation='softmax')
])

lstm_model_1.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
lstm_model_1.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 65, 32)            5888
#
#  lstm_10 (LSTM)              (None, 65, 64)            24832
#
#  lstm_11 (LSTM)              (None, 128)               98816
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 128)               0
#
#  flatten_14 (Flatten)        (None, 128)               0
#
#  dense_29 (Dense)            (None, 128)               16512
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 128)               0
#
#  dense_30 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 147338 (575.54 KB)
# Trainable params: 147338 (575.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = lstm_model_1.fit(inputs_train, targets_train,validation_data=(inputs_test, targets_test),epochs = 20,batch_size=80)
# Out:
# Epoch 1/20
# 100/100 [==============================] - 23s 186ms/step - loss: 1.6704 - accuracy: 0.3917 - val_loss: 1.4476 - val_accuracy: 0.4489
# Epoch 2/20
# 100/100 [==============================] - 16s 163ms/step - loss: 1.3680 - accuracy: 0.5036 - val_loss: 1.2601 - val_accuracy: 0.5501
# Epoch 3/20
# 100/100 [==============================] - 18s 180ms/step - loss: 1.2402 - accuracy: 0.5524 - val_loss: 1.2179 - val_accuracy: 0.5475
# Epoch 4/20
# 100/100 [==============================] - 20s 202ms/step - loss: 1.1626 - accuracy: 0.5838 - val_loss: 1.1593 - val_accuracy: 0.5701
# Epoch 5/20
# 100/100 [==============================] - 18s 178ms/step - loss: 1.0847 - accuracy: 0.6136 - val_loss: 1.1504 - val_accuracy: 0.5896
# Epoch 6/20
# 100/100 [==============================] - 16s 164ms/step - loss: 1.0411 - accuracy: 0.6225 - val_loss: 1.0534 - val_accuracy: 0.6271
# Epoch 7/20
# 100/100 [==============================] - 17s 171ms/step - loss: 0.9735 - accuracy: 0.6487 - val_loss: 1.0052 - val_accuracy: 0.6326
# Epoch 8/20
# 100/100 [==============================] - 17s 172ms/step - loss: 0.9208 - accuracy: 0.6666 - val_loss: 1.0294 - val_accuracy: 0.6346
# Epoch 9/20
# 100/100 [==============================] - 17s 175ms/step - loss: 0.8762 - accuracy: 0.6899 - val_loss: 1.0499 - val_accuracy: 0.6271
# Epoch 10/20
# 100/100 [==============================] - 18s 184ms/step - loss: 0.8610 - accuracy: 0.6920 - val_loss: 0.9681 - val_accuracy: 0.6602
# Epoch 11/20
# 100/100 [==============================] - 17s 174ms/step - loss: 0.7964 - accuracy: 0.7127 - val_loss: 0.9661 - val_accuracy: 0.6647
# Epoch 12/20
# 100/100 [==============================] - 18s 185ms/step - loss: 0.7910 - accuracy: 0.7209 - val_loss: 0.9451 - val_accuracy: 0.6777
# Epoch 13/20
# 100/100 [==============================] - 16s 165ms/step - loss: 0.7366 - accuracy: 0.7393 - val_loss: 0.9357 - val_accuracy: 0.6727
# Epoch 14/20
# 100/100 [==============================] - 18s 179ms/step - loss: 0.7299 - accuracy: 0.7391 - val_loss: 0.9340 - val_accuracy: 0.6867
# Epoch 15/20
# 100/100 [==============================] - 18s 184ms/step - loss: 0.6592 - accuracy: 0.7662 - val_loss: 0.9108 - val_accuracy: 0.6857
# Epoch 16/20
# 100/100 [==============================] - 22s 223ms/step - loss: 0.6553 - accuracy: 0.7667 - val_loss: 0.9208 - val_accuracy: 0.6892
# Epoch 17/20
# 100/100 [==============================] - 24s 245ms/step - loss: 0.5935 - accuracy: 0.7911 - val_loss: 0.9084 - val_accuracy: 0.6927
# Epoch 18/20
# 100/100 [==============================] - 21s 210ms/step - loss: 0.5708 - accuracy: 0.7990 - val_loss: 0.8943 - val_accuracy: 0.7137
# Epoch 19/20
# 100/100 [==============================] - 18s 178ms/step - loss: 0.5479 - accuracy: 0.8104 - val_loss: 0.9868 - val_accuracy: 0.6762
# Epoch 20/20
# 100/100 [==============================] - 17s 175ms/step - loss: 0.5488 - accuracy: 0.8007 - val_loss: 0.8955 - val_accuracy: 0.7097

# %%
#add batchnormalization
lstm_model_2 = Sequential([
    LSTM(32, return_sequences=True, input_shape=(inputs.shape[1], inputs.shape[2])),
    LSTM(64, return_sequences=True),
    LSTM(128),
    LeakyReLU(),
    BatchNormalization(),
    Flatten(),
    Dense(128),
    LeakyReLU(),
    Dense(10, activation='softmax')
])

lstm_model_2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
lstm_model_2.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 65, 32)            5888
#
#  lstm_13 (LSTM)              (None, 65, 64)            24832
#
#  lstm_14 (LSTM)              (None, 128)               98816
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 128)               0
#
#  batch_normalization_13 (Ba  (None, 128)               512
#  tchNormalization)
#
#  flatten_15 (Flatten)        (None, 128)               0
#
#  dense_31 (Dense)            (None, 128)               16512
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 128)               0
#
#  dense_32 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 147850 (577.54 KB)
# Trainable params: 147594 (576.54 KB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________

# %%
history_2 = lstm_model_2.fit(inputs_train, targets_train,validation_data=(inputs_test, targets_test),epochs = 20,batch_size=80)
# Out:
# Epoch 1/20
# 100/100 [==============================] - 18s 184ms/step - loss: 1.3045 - accuracy: 0.5283 - val_loss: 1.7694 - val_accuracy: 0.4580
# Epoch 2/20
# 100/100 [==============================] - 20s 201ms/step - loss: 1.1713 - accuracy: 0.5749 - val_loss: 1.4518 - val_accuracy: 0.5526
# Epoch 3/20
# 100/100 [==============================] - 17s 168ms/step - loss: 1.0790 - accuracy: 0.6142 - val_loss: 1.2219 - val_accuracy: 0.5861
# Epoch 4/20
# 100/100 [==============================] - 18s 178ms/step - loss: 0.9929 - accuracy: 0.6405 - val_loss: 1.1272 - val_accuracy: 0.5826
# Epoch 5/20
# 100/100 [==============================] - 18s 179ms/step - loss: 0.9352 - accuracy: 0.6607 - val_loss: 1.0132 - val_accuracy: 0.6346
# Epoch 6/20
# 100/100 [==============================] - 19s 189ms/step - loss: 0.8658 - accuracy: 0.6907 - val_loss: 0.9922 - val_accuracy: 0.6491
# Epoch 7/20
# 100/100 [==============================] - 17s 167ms/step - loss: 0.8207 - accuracy: 0.7063 - val_loss: 0.9708 - val_accuracy: 0.6577
# Epoch 8/20
# 100/100 [==============================] - 18s 183ms/step - loss: 0.7551 - accuracy: 0.7287 - val_loss: 0.9463 - val_accuracy: 0.6842
# Epoch 9/20
# 100/100 [==============================] - 18s 176ms/step - loss: 0.7199 - accuracy: 0.7416 - val_loss: 0.9607 - val_accuracy: 0.6682
# Epoch 10/20
# 100/100 [==============================] - 19s 188ms/step - loss: 0.6705 - accuracy: 0.7602 - val_loss: 0.9115 - val_accuracy: 0.6997
# Epoch 11/20
# 100/100 [==============================] - 26s 262ms/step - loss: 0.6473 - accuracy: 0.7740 - val_loss: 0.9660 - val_accuracy: 0.6902
# Epoch 12/20
# 100/100 [==============================] - 19s 195ms/step - loss: 0.6083 - accuracy: 0.7853 - val_loss: 0.9311 - val_accuracy: 0.6942
# Epoch 13/20
# 100/100 [==============================] - 17s 174ms/step - loss: 0.5662 - accuracy: 0.7986 - val_loss: 0.8786 - val_accuracy: 0.7087
# Epoch 14/20
# 100/100 [==============================] - 20s 204ms/step - loss: 0.5530 - accuracy: 0.8050 - val_loss: 0.8521 - val_accuracy: 0.7217
# Epoch 15/20
# 100/100 [==============================] - 21s 206ms/step - loss: 0.5118 - accuracy: 0.8190 - val_loss: 0.8797 - val_accuracy: 0.7092
# Epoch 16/20
# 100/100 [==============================] - 24s 244ms/step - loss: 0.4734 - accuracy: 0.8316 - val_loss: 0.8760 - val_accuracy: 0.7317
# Epoch 17/20
# 100/100 [==============================] - 18s 181ms/step - loss: 0.4651 - accuracy: 0.8329 - val_loss: 0.9014 - val_accuracy: 0.7187
# Epoch 18/20
# 100/100 [==============================] - 18s 184ms/step - loss: 0.4295 - accuracy: 0.8493 - val_loss: 0.8439 - val_accuracy: 0.7327
# Epoch 19/20
# 100/100 [==============================] - 18s 179ms/step - loss: 0.4158 - accuracy: 0.8545 - val_loss: 0.8853 - val_accuracy: 0.7247
# Epoch 20/20
# 100/100 [==============================] - 24s 241ms/step - loss: 0.3860 - accuracy: 0.8616 - val_loss: 0.9064 - val_accuracy: 0.7407

# %%
#add dropout layer
lstm_model_3 = Sequential([
    LSTM(32, return_sequences=True, input_shape=(inputs.shape[1], inputs.shape[2])),
    LSTM(64, return_sequences=True),
    LSTM(128),
    LeakyReLU(),
    Dropout(0.5),
    BatchNormalization(),
    Flatten(),
    Dense(128),
    LeakyReLU(),
    Dense(10, activation='softmax')
])

lstm_model_3.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
lstm_model_3.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_15 (LSTM)              (None, 65, 32)            5888
#
#  lstm_16 (LSTM)              (None, 65, 64)            24832
#
#  lstm_17 (LSTM)              (None, 128)               98816
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 128)               0
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  batch_normalization_14 (Ba  (None, 128)               512
#  tchNormalization)
#
#  flatten_16 (Flatten)        (None, 128)               0
#
#  dense_33 (Dense)            (None, 128)               16512
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 128)               0
#
#  dense_34 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 147850 (577.54 KB)
# Trainable params: 147594 (576.54 KB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________

# %%
history_3 = lstm_model_3.fit(inputs_train, targets_train,validation_data=(inputs_test, targets_test),epochs = 20,batch_size=80)
# Out:
# Epoch 1/20
# 100/100 [==============================] - 27s 216ms/step - loss: 1.7773 - accuracy: 0.3545 - val_loss: 1.8975 - val_accuracy: 0.4379
# Epoch 2/20
# 100/100 [==============================] - 19s 190ms/step - loss: 1.4563 - accuracy: 0.4594 - val_loss: 1.5833 - val_accuracy: 0.5080
# Epoch 3/20
# 100/100 [==============================] - 17s 166ms/step - loss: 1.3394 - accuracy: 0.5115 - val_loss: 1.4037 - val_accuracy: 0.5315
# Epoch 4/20
# 100/100 [==============================] - 18s 179ms/step - loss: 1.2453 - accuracy: 0.5525 - val_loss: 1.2094 - val_accuracy: 0.5846
# Epoch 5/20
# 100/100 [==============================] - 16s 165ms/step - loss: 1.1796 - accuracy: 0.5761 - val_loss: 1.1739 - val_accuracy: 0.5761
# Epoch 6/20
# 100/100 [==============================] - 17s 165ms/step - loss: 1.1174 - accuracy: 0.6077 - val_loss: 1.1603 - val_accuracy: 0.5871
# Epoch 7/20
# 100/100 [==============================] - 18s 178ms/step - loss: 1.0786 - accuracy: 0.6189 - val_loss: 1.1192 - val_accuracy: 0.6101
# Epoch 8/20
# 100/100 [==============================] - 16s 163ms/step - loss: 1.0193 - accuracy: 0.6417 - val_loss: 1.0694 - val_accuracy: 0.6251
# Epoch 9/20
# 100/100 [==============================] - 20s 204ms/step - loss: 0.9645 - accuracy: 0.6600 - val_loss: 1.0346 - val_accuracy: 0.6346
# Epoch 10/20
# 100/100 [==============================] - 20s 203ms/step - loss: 0.9302 - accuracy: 0.6829 - val_loss: 1.0839 - val_accuracy: 0.6176
# Epoch 11/20
# 100/100 [==============================] - 23s 234ms/step - loss: 0.9094 - accuracy: 0.6859 - val_loss: 1.0410 - val_accuracy: 0.6296
# Epoch 12/20
# 100/100 [==============================] - 22s 217ms/step - loss: 0.8753 - accuracy: 0.6985 - val_loss: 1.0042 - val_accuracy: 0.6557
# Epoch 13/20
# 100/100 [==============================] - 18s 177ms/step - loss: 0.8275 - accuracy: 0.7158 - val_loss: 0.9950 - val_accuracy: 0.6517
# Epoch 14/20
# 100/100 [==============================] - 31s 304ms/step - loss: 0.7995 - accuracy: 0.7218 - val_loss: 1.0268 - val_accuracy: 0.6527
# Epoch 15/20
# 100/100 [==============================] - 18s 185ms/step - loss: 0.7876 - accuracy: 0.7258 - val_loss: 0.9446 - val_accuracy: 0.6762
# Epoch 16/20
# 100/100 [==============================] - 19s 192ms/step - loss: 0.7491 - accuracy: 0.7422 - val_loss: 0.9942 - val_accuracy: 0.6802
# Epoch 17/20
# 100/100 [==============================] - 18s 183ms/step - loss: 0.7383 - accuracy: 0.7495 - val_loss: 0.9553 - val_accuracy: 0.6887
# Epoch 18/20
# 100/100 [==============================] - 21s 210ms/step - loss: 0.7087 - accuracy: 0.7594 - val_loss: 0.9914 - val_accuracy: 0.6742
# Epoch 19/20
# 100/100 [==============================] - 20s 200ms/step - loss: 0.6796 - accuracy: 0.7664 - val_loss: 0.9140 - val_accuracy: 0.6932
# Epoch 20/20
# 100/100 [==============================] - 30s 299ms/step - loss: 0.6696 - accuracy: 0.7751 - val_loss: 0.9406 - val_accuracy: 0.6937

# %% [markdown]
# # **CNN**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

cnn_model_1 = Sequential([
    Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(inputs.shape[1], inputs.shape[2], 1)),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

cnn_model_1.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
cnn_model_1.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_25 (Conv2D)          (None, 63, 11, 32)        320
#
#  max_pooling2d_25 (MaxPooli  (None, 31, 5, 32)         0
#  ng2D)
#
#  conv2d_26 (Conv2D)          (None, 29, 3, 64)         18496
#
#  max_pooling2d_26 (MaxPooli  (None, 14, 1, 64)         0
#  ng2D)
#
#  flatten_17 (Flatten)        (None, 896)               0
#
#  dense_35 (Dense)            (None, 128)               114816
#
#  dense_36 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 134922 (527.04 KB)
# Trainable params: 134922 (527.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history_4 = cnn_model_1.fit(inputs_train, targets_train,validation_data=(inputs_test, targets_test),epochs = 20,batch_size=80)
# Out:
# Epoch 1/20
# 100/100 [==============================] - 5s 40ms/step - loss: 2.1638 - accuracy: 0.3739 - val_loss: 1.5061 - val_accuracy: 0.4449
# Epoch 2/20
# 100/100 [==============================] - 3s 33ms/step - loss: 1.4086 - accuracy: 0.4844 - val_loss: 1.3414 - val_accuracy: 0.5045
# Epoch 3/20
# 100/100 [==============================] - 3s 32ms/step - loss: 1.2610 - accuracy: 0.5355 - val_loss: 1.2843 - val_accuracy: 0.5315
# Epoch 4/20
# 100/100 [==============================] - 4s 42ms/step - loss: 1.1409 - accuracy: 0.5830 - val_loss: 1.2377 - val_accuracy: 0.5581
# Epoch 5/20
# 100/100 [==============================] - 3s 34ms/step - loss: 1.0701 - accuracy: 0.6086 - val_loss: 1.1421 - val_accuracy: 0.5841
# Epoch 6/20
# 100/100 [==============================] - 3s 33ms/step - loss: 0.9827 - accuracy: 0.6472 - val_loss: 1.1410 - val_accuracy: 0.5841
# Epoch 7/20
# 100/100 [==============================] - 4s 41ms/step - loss: 0.8983 - accuracy: 0.6731 - val_loss: 1.0525 - val_accuracy: 0.6196
# Epoch 8/20
# 100/100 [==============================] - 3s 34ms/step - loss: 0.7979 - accuracy: 0.7152 - val_loss: 1.0586 - val_accuracy: 0.6281
# Epoch 9/20
# 100/100 [==============================] - 3s 33ms/step - loss: 0.7360 - accuracy: 0.7405 - val_loss: 1.0562 - val_accuracy: 0.6236
# Epoch 10/20
# 100/100 [==============================] - 3s 33ms/step - loss: 0.6741 - accuracy: 0.7641 - val_loss: 1.0589 - val_accuracy: 0.6321
# Epoch 11/20
# 100/100 [==============================] - 4s 41ms/step - loss: 0.6355 - accuracy: 0.7781 - val_loss: 1.0313 - val_accuracy: 0.6607
# Epoch 12/20
# 100/100 [==============================] - 3s 34ms/step - loss: 0.5275 - accuracy: 0.8188 - val_loss: 1.1051 - val_accuracy: 0.6527
# Epoch 13/20
# 100/100 [==============================] - 4s 37ms/step - loss: 0.4844 - accuracy: 0.8309 - val_loss: 1.0858 - val_accuracy: 0.6617
# Epoch 14/20
# 100/100 [==============================] - 4s 42ms/step - loss: 0.4167 - accuracy: 0.8570 - val_loss: 1.0899 - val_accuracy: 0.6762
# Epoch 15/20
# 100/100 [==============================] - 3s 33ms/step - loss: 0.3927 - accuracy: 0.8656 - val_loss: 1.1066 - val_accuracy: 0.6722
# Epoch 16/20
# 100/100 [==============================] - 3s 33ms/step - loss: 0.3360 - accuracy: 0.8886 - val_loss: 1.1287 - val_accuracy: 0.6727
# Epoch 17/20
# 100/100 [==============================] - 4s 36ms/step - loss: 0.2927 - accuracy: 0.9038 - val_loss: 1.1523 - val_accuracy: 0.6722
# Epoch 18/20
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2532 - accuracy: 0.9145 - val_loss: 1.2261 - val_accuracy: 0.6737
# Epoch 19/20
# 100/100 [==============================] - 3s 34ms/step - loss: 0.2262 - accuracy: 0.9238 - val_loss: 1.3718 - val_accuracy: 0.6466
# Epoch 20/20
# 100/100 [==============================] - 3s 34ms/step - loss: 0.1989 - accuracy: 0.9366 - val_loss: 1.4582 - val_accuracy: 0.6622

# %%
#add batchnormalization
cnn_model_2 = Sequential([
    Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(inputs.shape[1], inputs.shape[2], 1)),
    BatchNormalization(),  # Helps to normalize the inputs of the activation layer to improve training
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

cnn_model_2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
cnn_model_2.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_27 (Conv2D)          (None, 63, 11, 32)        320
#
#  batch_normalization_15 (Ba  (None, 63, 11, 32)        128
#  tchNormalization)
#
#  max_pooling2d_27 (MaxPooli  (None, 31, 5, 32)         0
#  ng2D)
#
#  conv2d_28 (Conv2D)          (None, 29, 3, 64)         18496
#
#  batch_normalization_16 (Ba  (None, 29, 3, 64)         256
#  tchNormalization)
#
#  max_pooling2d_28 (MaxPooli  (None, 14, 1, 64)         0
#  ng2D)
#
#  flatten_18 (Flatten)        (None, 896)               0
#
#  dense_37 (Dense)            (None, 128)               114816
#
#  dense_38 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 135306 (528.54 KB)
# Trainable params: 135114 (527.79 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %%
history_5 = cnn_model_2.fit(inputs_train, targets_train,validation_data=(inputs_test, targets_test),epochs = 20,batch_size=80)
# Out:
# Epoch 1/20
# 100/100 [==============================] - 6s 55ms/step - loss: 1.5234 - accuracy: 0.4633 - val_loss: 1.5785 - val_accuracy: 0.4234
# Epoch 2/20
# 100/100 [==============================] - 4s 45ms/step - loss: 1.0589 - accuracy: 0.6193 - val_loss: 1.1498 - val_accuracy: 0.5961
# Epoch 3/20
# 100/100 [==============================] - 5s 52ms/step - loss: 0.8667 - accuracy: 0.6999 - val_loss: 1.0142 - val_accuracy: 0.6466
# Epoch 4/20
# 100/100 [==============================] - 5s 45ms/step - loss: 0.6971 - accuracy: 0.7602 - val_loss: 0.9410 - val_accuracy: 0.6802
# Epoch 5/20
# 100/100 [==============================] - 4s 45ms/step - loss: 0.5856 - accuracy: 0.7999 - val_loss: 0.9070 - val_accuracy: 0.6952
# Epoch 6/20
# 100/100 [==============================] - 6s 56ms/step - loss: 0.4572 - accuracy: 0.8468 - val_loss: 0.9417 - val_accuracy: 0.6812
# Epoch 7/20
# 100/100 [==============================] - 4s 45ms/step - loss: 0.3611 - accuracy: 0.8852 - val_loss: 0.8681 - val_accuracy: 0.7122
# Epoch 8/20
# 100/100 [==============================] - 5s 53ms/step - loss: 0.2643 - accuracy: 0.9217 - val_loss: 1.0346 - val_accuracy: 0.6752
# Epoch 9/20
# 100/100 [==============================] - 5s 47ms/step - loss: 0.2108 - accuracy: 0.9352 - val_loss: 0.9390 - val_accuracy: 0.7162
# Epoch 10/20
# 100/100 [==============================] - 5s 45ms/step - loss: 0.1658 - accuracy: 0.9511 - val_loss: 1.0001 - val_accuracy: 0.7032
# Epoch 11/20
# 100/100 [==============================] - 5s 54ms/step - loss: 0.1175 - accuracy: 0.9676 - val_loss: 1.1299 - val_accuracy: 0.6837
# Epoch 12/20
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0963 - accuracy: 0.9725 - val_loss: 0.9469 - val_accuracy: 0.7212
# Epoch 13/20
# 100/100 [==============================] - 6s 58ms/step - loss: 0.0644 - accuracy: 0.9857 - val_loss: 1.0880 - val_accuracy: 0.7172
# Epoch 14/20
# 100/100 [==============================] - 8s 76ms/step - loss: 0.0577 - accuracy: 0.9867 - val_loss: 1.0781 - val_accuracy: 0.7132
# Epoch 15/20
# 100/100 [==============================] - 10s 97ms/step - loss: 0.0434 - accuracy: 0.9906 - val_loss: 1.0374 - val_accuracy: 0.7327
# Epoch 16/20
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0370 - accuracy: 0.9937 - val_loss: 1.0642 - val_accuracy: 0.7307
# Epoch 17/20
# 100/100 [==============================] - 6s 57ms/step - loss: 0.0252 - accuracy: 0.9962 - val_loss: 1.0179 - val_accuracy: 0.7382
# Epoch 18/20
# 100/100 [==============================] - 5s 52ms/step - loss: 0.0204 - accuracy: 0.9972 - val_loss: 1.0793 - val_accuracy: 0.7337
# Epoch 19/20
# 100/100 [==============================] - 5s 45ms/step - loss: 0.0174 - accuracy: 0.9972 - val_loss: 1.0797 - val_accuracy: 0.7462
# Epoch 20/20
# 100/100 [==============================] - 4s 44ms/step - loss: 0.0290 - accuracy: 0.9939 - val_loss: 1.3758 - val_accuracy: 0.7112

# %%
#add dropout layer
cnn_model_3 = Sequential([
    Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(inputs.shape[1], inputs.shape[2], 1)),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),  # Add dropout to reduce overfitting
    Dense(10, activation='softmax')
])

cnn_model_3.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
cnn_model_3.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_29 (Conv2D)          (None, 63, 11, 32)        320
#
#  batch_normalization_17 (Ba  (None, 63, 11, 32)        128
#  tchNormalization)
#
#  max_pooling2d_29 (MaxPooli  (None, 31, 5, 32)         0
#  ng2D)
#
#  conv2d_30 (Conv2D)          (None, 29, 3, 64)         18496
#
#  batch_normalization_18 (Ba  (None, 29, 3, 64)         256
#  tchNormalization)
#
#  max_pooling2d_30 (MaxPooli  (None, 14, 1, 64)         0
#  ng2D)
#
#  flatten_19 (Flatten)        (None, 896)               0
#
#  dense_39 (Dense)            (None, 128)               114816
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_40 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 135306 (528.54 KB)
# Trainable params: 135114 (527.79 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %%
history_6 = cnn_model_3.fit(inputs_train, targets_train,validation_data=(inputs_test, targets_test),epochs = 20,batch_size=80)
# Out:
# Epoch 1/20
# 100/100 [==============================] - 6s 56ms/step - loss: 1.9137 - accuracy: 0.3540 - val_loss: 1.6945 - val_accuracy: 0.3729
# Epoch 2/20
# 100/100 [==============================] - 4s 45ms/step - loss: 1.4742 - accuracy: 0.4636 - val_loss: 1.3668 - val_accuracy: 0.5070
# Epoch 3/20
# 100/100 [==============================] - 4s 44ms/step - loss: 1.3036 - accuracy: 0.5283 - val_loss: 1.1501 - val_accuracy: 0.5816
# Epoch 4/20
# 100/100 [==============================] - 5s 54ms/step - loss: 1.1647 - accuracy: 0.5785 - val_loss: 1.0446 - val_accuracy: 0.6166
# Epoch 5/20
# 100/100 [==============================] - 4s 45ms/step - loss: 1.0689 - accuracy: 0.6132 - val_loss: 1.0693 - val_accuracy: 0.6206
# Epoch 6/20
# 100/100 [==============================] - 5s 53ms/step - loss: 0.9979 - accuracy: 0.6413 - val_loss: 0.9208 - val_accuracy: 0.6707
# Epoch 7/20
# 100/100 [==============================] - 5s 45ms/step - loss: 0.9514 - accuracy: 0.6585 - val_loss: 0.9071 - val_accuracy: 0.6732
# Epoch 8/20
# 100/100 [==============================] - 5s 45ms/step - loss: 0.8680 - accuracy: 0.6889 - val_loss: 0.9366 - val_accuracy: 0.6722
# Epoch 9/20
# 100/100 [==============================] - 6s 60ms/step - loss: 0.8087 - accuracy: 0.7108 - val_loss: 0.8899 - val_accuracy: 0.6852
# Epoch 10/20
# 100/100 [==============================] - 5s 45ms/step - loss: 0.7693 - accuracy: 0.7253 - val_loss: 0.8595 - val_accuracy: 0.7122
# Epoch 11/20
# 100/100 [==============================] - 6s 56ms/step - loss: 0.7154 - accuracy: 0.7366 - val_loss: 0.8626 - val_accuracy: 0.6892
# Epoch 12/20
# 100/100 [==============================] - 4s 45ms/step - loss: 0.6539 - accuracy: 0.7634 - val_loss: 0.7970 - val_accuracy: 0.7272
# Epoch 13/20
# 100/100 [==============================] - 4s 44ms/step - loss: 0.6311 - accuracy: 0.7793 - val_loss: 0.7578 - val_accuracy: 0.7372
# Epoch 14/20
# 100/100 [==============================] - 5s 53ms/step - loss: 0.5957 - accuracy: 0.7906 - val_loss: 0.7827 - val_accuracy: 0.7357
# Epoch 15/20
# 100/100 [==============================] - 4s 44ms/step - loss: 0.5419 - accuracy: 0.8080 - val_loss: 0.7468 - val_accuracy: 0.7427
# Epoch 16/20
# 100/100 [==============================] - 5s 55ms/step - loss: 0.5310 - accuracy: 0.8137 - val_loss: 0.8297 - val_accuracy: 0.7292
# Epoch 17/20
# 100/100 [==============================] - 4s 45ms/step - loss: 0.5063 - accuracy: 0.8185 - val_loss: 0.7711 - val_accuracy: 0.7472
# Epoch 18/20
# 100/100 [==============================] - 5s 45ms/step - loss: 0.4686 - accuracy: 0.8309 - val_loss: 0.8363 - val_accuracy: 0.7287
# Epoch 19/20
# 100/100 [==============================] - 5s 54ms/step - loss: 0.4388 - accuracy: 0.8399 - val_loss: 0.7960 - val_accuracy: 0.7513
# Epoch 20/20
# 100/100 [==============================] - 5s 45ms/step - loss: 0.4352 - accuracy: 0.8448 - val_loss: 0.9091 - val_accuracy: 0.7332

# %%
data = pd.DataFrame({'Model': [ 'LSTM_1','LSTM_2_BN','LSTM_3_BN_DROPOUT','CNN_1', 'CNN_2_BN', 'CNN_3_BN_DROPOUT'],
        'Test Accuracy': [history.history['val_accuracy'][-1], history_2.history['val_accuracy'][-1], history_3.history['val_accuracy'][-1],
                          history_4.history['val_accuracy'][-1],history_5.history['val_accuracy'][-1],history_6.history['val_accuracy'][-1]],
         'Test Loss': [history.history['val_loss'][-1], history_2.history['val_loss'][-1], history_3.history['val_loss'][-1],
                          history_4.history['val_loss'][-1],history_5.history['val_loss'][-1],history_6.history['val_loss'][-1]]        })
data
# Out:
#                Model  Test Accuracy  Test Loss
# 0             LSTM_1       0.709710   0.895483
# 1          LSTM_2_BN       0.740741   0.906434
# 2  LSTM_3_BN_DROPOUT       0.693694   0.940629
# 3              CNN_1       0.662162   1.458174
# 4           CNN_2_BN       0.711211   1.375765
# 5   CNN_3_BN_DROPOUT       0.733233   0.909082

# %%
#classification report for the best lstm and cnn
predictions_lstm = lstm_model_2.predict(inputs_test)
predicted_classes_lstm = predictions_lstm.argmax(axis=1)

predictions_cnn = cnn_model_3.predict(inputs_test)
predicted_classes_cnn = predictions_cnn.argmax(axis=1)

true_classes = targets_test


from sklearn.metrics import classification_report
report_lstm = classification_report(true_classes, predicted_classes_lstm)
print("Classification Report for LSTM Model:")
print(report_lstm)
report_cnn = classification_report(true_classes, predicted_classes_cnn)
print("\nClassification Report for CNN Model:")
print(report_cnn)
# Out:
# 63/63 [==============================] - 3s 29ms/step
# 63/63 [==============================] - 0s 6ms/step
# Classification Report for LSTM Model:
#               precision    recall  f1-score   support
#
#            0       0.65      0.80      0.71       210
#            1       0.86      0.95      0.90       216
#            2       0.72      0.69      0.70       210
#            3       0.90      0.85      0.87       170
#            4       0.65      0.50      0.56       199
#            5       0.87      0.66      0.75       216
#            6       0.84      0.77      0.80       208
#            7       0.81      0.76      0.78       188
#            8       0.67      0.72      0.70       191
#            9       0.55      0.72      0.62       190
#
#     accuracy                           0.74      1998
#    macro avg       0.75      0.74      0.74      1998
# weighted avg       0.75      0.74      0.74      1998
#
#
# Classification Report for CNN Model:
#               precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70       210
#            1       0.93      0.90      0.92       216
#            2       0.56      0.87      0.68       210
#            3       0.74      0.88      0.80       170
#            4       0.67      0.42      0.52       199
#            5       0.79      0.86      0.82       216
#            6       0.86      0.75      0.80       208
#            7       0.77      0.61      0.68       188
#            8       0.69      0.68      0.68       191
#            9       0.71      0.64      0.67       190
#
#     accuracy                           0.73      1998
#    macro avg       0.74      0.73      0.73      1998
# weighted avg       0.74      0.73      0.73      1998
